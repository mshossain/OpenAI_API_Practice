# %%
# pip install openai
from openai import OpenAI
import base64
from IPython.display import Image, display

# https://platform.openai.com/docs/guides/text-generation

# %%
# Load API key from a file
with open("key.txt", "r") as file:
    my_api_key = file.read().strip()

# %%
image_path="pic_vegetable.jpg"

# %%
with open(image_path, "rb") as image_file:
    image_base64 = base64.b64encode(image_file.read()).decode('utf-8')

# %%
# Display the image
display(Image(data=base64.b64decode(image_base64)))

# %%
client = OpenAI(api_key=my_api_key)

# %%
completion = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "What's in this image?"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{image_base64}",
                    }
                },
            ],
        }
    ],
)

# %%
print(completion.choices[0].message.content)
# Out:
# The image shows a small outdoor stove with a cast iron skillet on top, cooking a variety of vegetables. The vegetables include broccoli, mushrooms, bell peppers, onions, and zucchini. There are some pieces of wood stacked next to the stove, which is resting on a set of tiles. The stove has a fire burning inside, visible through a glass window.
